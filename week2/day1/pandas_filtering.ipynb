# %% [markdown]
# # Week 2 Day 1: pandas Filtering
#
# Filter rows, create revenue, and begin explaining analysis choices.

# %%
from pathlib import Path
import pandas as pd

sales = pd.read_csv(Path.cwd() / 'data' / 'sample' / 'sales_sample.csv')
sales['revenue'] = sales['price'] * sales['quantity']
sales.head()

# %%
# TODO: filter to one category
# TODO: filter to revenue >= 100
# TODO: group revenue by category

# %% [markdown]
# ## Reflection
#
# Write one sentence explaining why you chose your filter.
