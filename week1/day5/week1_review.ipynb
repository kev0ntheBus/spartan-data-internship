# %% [markdown]
# # Week 1 Review
#
# Review Python, SQL concepts, and pandas basics.

# %%
# TODO: write a function that averages a list of numbers

# %%
# TODO: read data/sample/sales_sample.csv with pandas
# TODO: add a revenue column

# %% [markdown]
# ## Reflection
#
# Write the three fundamentals you need to repeat most.
