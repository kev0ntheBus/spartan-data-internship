# %% [markdown]
# # Week 1 Day 4: pandas Intro
#
# A DataFrame is like a table. A Series is like one column.

# %%
from pathlib import Path
import pandas as pd

repo_root = Path.cwd()
employees = pd.read_csv(repo_root / 'data' / 'sample' / 'employees.csv')
employees.head()

# %%
employees.info()

# %%
employees['salary'].describe()

# %%
# TODO: filter to one department
# TODO: sort by salary
# TODO: add a new column
