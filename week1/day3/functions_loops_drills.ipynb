# %% [markdown]
# # Week 1 Day 3: Functions and Loops
#
# Practice looping through nested data and writing small functions.

# %%
employees = [
    {'name': 'Ava', 'department': 'Analytics', 'salary': 82000},
    {'name': 'Ben', 'department': 'Engineering', 'salary': 91000},
]

for employee in employees:
    print(employee['name'], employee['department'])

# %%
# TODO: write a function that returns True if salary >= 85000

# TODO: loop through employees and use the function
