# %% [markdown]
# # Week 1 Day 2: Python Drills
#
# Use this notebook for repetition. Fill in the TODOs.

# %%
# TODO: create three variables

# TODO: print each variable

# %%
# TODO: create a list of topics

# TODO: loop through the list

# %%
# TODO: write a function called add_two_numbers
