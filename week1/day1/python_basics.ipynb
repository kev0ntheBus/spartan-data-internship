# %% [markdown]
# # Week 1 Day 1: Python Basics
#
# Start from zero. Run each cell slowly and read the output.

# %%
print('Hello, Spartan Data Internship')

# %% [markdown]
# ## Variables and Types
#
# A variable is a name that stores a value.

# %%
name = 'Kevin'
week = 1
hours = 2.5
is_learning = True

print(name, week, hours, is_learning)
print(type(name), type(week), type(hours), type(is_learning))

# %% [markdown]
# ## Lists, Dictionaries, Loops, and Functions

# %%
skills = ['Python', 'SQL', 'pandas']
learner = {'name': 'Kevin', 'week': 1}

for skill in skills:
    print('Practice:', skill)

def greet(person_name):
    return f'Hello, {person_name}'

print(greet(learner['name']))

# %% [markdown]
# ## TODO
#
# Add one new variable, one new list item, and one new function.
